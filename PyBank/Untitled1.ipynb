# %%
import pandas as pd
import numpy as np

# file = "budget_data.csv"

# df = pd.read_csv(file)


# Total Profit_Losses = df['Profit/Losses'].sum()

# Total Profit_Losses

# # print df['distance'].sum()

# %%
file = "budget_data.csv"

df = pd.read_csv(file)
df2 = 
plsum = df['Profit/Losses'].sum()
monsum = df['Date'].count()
avgchg = (df.iloc[-1][1] - df.iloc[0][1])  / df['Profit/Losses'].count()
plmin = df['Profit/Losses'].iloc[0, df['Profit/Losses'].min()]
plmax = df.max()

print(f'Total Months: {monsum}')
print(f'Total Profit/Losses: {plsum}')
print(f'Average Change: {avgchg}')
print(f'Max Profit: {plmin}')
print(f'Min Change: {avgchg}')
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-91-0938c489b641> in <module>
#       6 monsum = df['Date'].count()
#       7 avgchg = (df.iloc[-1][1] - df.iloc[0][1])  / df['Profit/Losses'].count()
# ----> 8 plmin = df['Profit/Losses'].iloc[0, df['Profit/Losses'].min()]
#       9 plmax = df.max()
#      10
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-5fe2f43a50f7> in <module>
# ----> 1 avgchg.np.dtype()
#
# AttributeError: 'numpy.float64' object has no attribute 'np'

# %%
df.max()
# Out:
# Date             Sep-2016
# Profit/Losses     1170593
# dtype: object

# %%
df.min()
# Out:
#                  Apr-2010
# Date               ...
# Profit/Losses    -1196225
# Length: 2, dtype: object

# %%
pd.set_option('display.max_rows', -1)

# %%
df
# Out:
# ..       ...     ...
#         Date  Profit/Losses
# 0   Jan-2010  867884
# 1   Feb-2010  984655
# 2   Mar-2010  322013
# 3   Apr-2010 -69417
# 4   May-2010  310503
# 5   Jun-2010  522857
# 6   Jul-2010  1033096
# 7   Aug-2010  604885
# 8   Sep-2010 -216386
# 9   Oct-2010  477532
# 10  Nov-2010  893810
# 11  Dec-2010 -80353
# 12  Jan-2011  779806
# 13  Feb-2011 -335203
# 14  Mar-2011  697845
# 15  Apr-2011  793163
# 16  May-2011  485070
# 17  Jun-2011  584122
# 18  Jul-2011  62729
# 19  Aug-2011  668179
# 20  Sep-2011  899906
# 21  Oct-2011  834719
# 22  Nov-2011  132003
# 23  Dec-2011  309978
# 24  Jan-2012 -755566
# 25  Feb-2012  1170593
# 26  Mar-2012  252788
# 27  Apr-2012  1151518
# 28  May-2012  817256
# 29  Jun-2012  570757
# 30  Jul-2012  506702
# 31  Aug-2012 -1022534
# 32  Sep-2012  475062
# 33  Oct-2012  779976
# 34  Nov-2012  144175
# 35  Dec-2012  542494
# 36  Jan-2013  359333
# 37  Feb-2013  321469
# 38  Mar-2013  67780
# 39  Apr-2013  471435
# 40  May-2013  565603
# ...
